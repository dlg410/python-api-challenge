# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import datetime
from scipy.stats import linregress
import scipy.stats as st

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 608

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Config information.

url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL

query_url = f"{url}appid={weather_api_key}&units={units}&q="

# %%
# set up lists to hold reponse info

lat = []
temp = []
temp_max = []
humidity = []
wind_speed = []
lon = []
date = []
country = []
cloudiness = []


# Loop through the list of cities and perform a request for data on each
print("Beginning Data Retrieval")
print("--------------------------------------------")
count = 0
set = 1
for idx, city in enumerate(cities):
    count = count + 1
    if count == 51:
        count = 1
        set = set + 1
        time.sleep(5)
    print(f"Processing Record {count} of Set {set} | {city}")
    try:
        response = requests.get(query_url + city).json()
        lat.append(response['coord']['lat'])
        lon.append(response['coord']['lon'])
        temp.append(response['main']['temp'])
        temp_max.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        wind_speed.append(response['wind']['speed'])
        date.append(response['dt'])
        country.append(response['sys']['country'])
        cloudiness.append(response['clouds']['all'])
    except KeyError:
        print("City not found. Skipping...")
        lat.append(np.nan)
        lon.append(np.nan)
        temp.append(np.nan)
        temp_max.append(np.nan)
        humidity.append(np.nan)
        wind_speed.append(np.nan)
        date.append(np.nan)
        country.append(np.nan)
        cloudiness.append(np.nan)
print("Data Retrieval Complete")
print("------------------------------------------------")
# Out:
# Beginning Data Retrieval
# --------------------------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | poum
# Processing Record 3 of Set 1 | avarua
# Processing Record 4 of Set 1 | severiano melo
# Processing Record 5 of Set 1 | akure
# Processing Record 6 of Set 1 | port lincoln
# Processing Record 7 of Set 1 | vaini
# Processing Record 8 of Set 1 | veraval
# Processing Record 9 of Set 1 | samarai
# Processing Record 10 of Set 1 | carnarvon
# Processing Record 11 of Set 1 | parfino
# Processing Record 12 of Set 1 | hobart
# Processing Record 13 of Set 1 | hersbruck
# Processing Record 14 of Set 1 | hami
# Processing Record 15 of Set 1 | tamandare
# Processing Record 16 of Set 1 | mataura
# Processing Record 17 of Set 1 | severo-kurilsk
# Processing Record 18 of Set 1 | zyryanka
# Processing Record 19 of Set 1 | qaanaaq
# Processing Record 20 of Set 1 | rikitea
# Processing Record 21 of Set 1 | khatanga
# Processing Record 22 of Set 1 | oksfjord
# Processing Record 23 of Set 1 | hilo
# Processing Record 24 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 25 of Set 1 | saskylakh
# Processing Record 26 of Set 1 | puerto ayora
# Processing Record 27 of Set 1 | teya
# Processing Record 28 of Set 1 | hasaki
# Processing Record 29 of Set 1 | albany
# Processing Record 30 of Set 1 | cape town
# Processing Record 31 of Set 1 | jadu
# Processing Record 32 of Set 1 | yerani
# City not found. Skipping...
# Processing Record 33 of Set 1 | marawi
# Processing Record 34 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 35 of Set 1 | bredasdorp
# Processing Record 36 of Set 1 | dikson
# Processing Record 37 of Set 1 | north bend
# Processing Record 38 of Set 1 | rioja
# Processing Record 39 of Set 1 | cabedelo
# Processing Record 40 of Set 1 | lavrentiya
# Processing Record 41 of Set 1 | pevek
# Processing Record 42 of Set 1 | moose factory
# Processing Record 43 of Set 1 | lao cai
# Processing Record 44 of Set 1 | barrow
# Processing Record 45 of Set 1 | mar del plata
# Processing Record 46 of Set 1 | nikolskoye
# Processing Record 47 of Set 1 | gamba
# Processing Record 48 of Set 1 | yellowknife
# Processing Record 49 of Set 1 | te anau
# Processing Record 39 of Set 4 | martinsville
# Processing Record 40 of Set 4 | kuusamo
# Processing Record 41 of Set 4 | orikum
# Processing Record 42 of Set 4 | eidsvag
# Processing Record 43 of Set 4 | pacasmayo
# Processing Record 44 of Set 4 | virginia beach
# Processing Record 45 of Set 4 | coihaique
# Processing Record 46 of Set 4 | dong hoi
# Processing Record 47 of Set 4 | sabang
# Processing Record 48 of Set 4 | iqaluit
# Processing Record 49 of Set 4 | noumea
# Processing Record 50 of Set 4 | abonnema
# Processing Record 1 of Set 5 | georgetown
# Processing Record 2 of Set 5 | sao joao da barra
# Processing Record 3 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 4 of Set 5 | matara
# Processing Record 5 of Set 5 | ponta do sol
# Processing Record 6 of Set 5 | nemuro
# Processing Record 7 of Set 5 | paamiut
# Processing Record 8 of Set 5 | kaputa
# Processing Record 9 of Set 5 | saint george
# Processing Record 10 of Set 5 | mogadishu
# Processing Record 11 of Set 5 | north platte
# Processing Record 12 of Set 5 | richards bay
# Processing Record 13 of Set 5 | khonuu
# City not found. Skipping...
# Processing Record 14 of Set 5 | college
# Processing Record 15 of Set 5 | vila franca do campo
# Processing Record 16 of Set 5 | luderitz
# Processing Record 17 of Set 5 | kasongo-lunda
# Processing Record 18 of Set 5 | hamilton
# Processing Record 19 of Set 5 | beloha
# Processing Record 20 of Set 5 | matagami
# Processing Record 21 of Set 5 | sohbatpur
# Processing Record 22 of Set 5 | shingu
# Processing Record 23 of Set 5 | khorinsk
# Processing Record 24 of Set 5 | san carlos de bariloche
# Processing Record 25 of Set 5 | bethel
# Processing Record 26 of Set 5 | itarema
# Processing Record 27 of Set 5 | kavieng
# Processing Record 28 of Set 5 | chokurdakh
# Processing Record 29 of Set 5 | yanan
# City not found. Skipping...
# Processing Record 30 of Set 5 | fleetwood
# Processing Record 31 of Set 5 | gedo
# Processing Record 32 of Set 5 | mutsamudu
# City not found. Skipping...
# Processing Record 33 of Set 5 | boddam
# Processing Record 34 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 35 of Set 5 | najran
# Processing Record 36 of Set 5 | buchanan
# Processing Record 37 of Set 5 | pran buri
# Processing Record 38 of Set 5 | zaozerne
# Processing Record 39 of Set 5 | yeniseysk
# Processing Record 40 of Set 5 | gurskoye
# City not found. Skipping...
# Processing Record 41 of Set 5 | onega
# Processing Record 42 of Set 5 | east london
# Processing Record 43 of Set 5 | amga
# Processing Record 44 of Set 5 | fortuna
# Processing Record 45 of Set 5 | paris
# Processing Record 46 of Set 5 | yeppoon
# Processing Record 47 of Set 5 | poya
# Processing Record 48 of Set 5 | adrar
# Processing Record 49 of Set 5 | yamnytsya
# Processing Record 50 of Set 5 | vila velha
# Processing Record 1 of Set 6 | ahuimanu
# Processing Record 2 of Set 6 | iquitos
# Processing Record 3 of Set 6 | hualmay
# Processing Record 4 of Set 6 | alta floresta
# Processing Record 5 of Set 6 | hofn
# Processing Record 6 of Set 6 | saint-georges
# Processing Record 7 of Set 6 | along
# Processing Record 8 of Set 6 | gobabis
# Processing Record 9 of Set 6 | camapua
# Processing Record 10 of Set 6 | pyaozerskiy
# Processing Record 11 of Set 6 | nanortalik
# Processing Record 12 of Set 6 | jalingo
# Processing Record 13 of Set 6 | kudahuvadhoo
# Processing Record 14 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 15 of Set 6 | ribeira grande
# Processing Record 16 of Set 6 | slidell
# Processing Record 17 of Set 6 | salalah
# Processing Record 18 of Set 6 | alzamay
# Processing Record 19 of Set 6 | quincy
# Processing Record 20 of Set 6 | meulaboh
# Processing Record 21 of Set 6 | suntar
# Processing Record 22 of Set 6 | cidreira
# Processing Record 23 of Set 6 | padampur
# Processing Record 24 of Set 6 | baykit
# Processing Record 25 of Set 6 | itacoatiara
# Processing Record 26 of Set 6 | buraydah
# Processing Record 27 of Set 6 | namatanai
# Processing Record 28 of Set 6 | longlac
# City not found. Skipping...
# Processing Record 29 of Set 6 | asau
# Processing Record 30 of Set 6 | wilmington
# Processing Record 31 of Set 6 | wankaner
# Processing Record 32 of Set 6 | klyuchi
# Processing Record 33 of Set 6 | luganville
# Processing Record 34 of Set 6 | cap malheureux
# Processing Record 35 of Set 6 | paracatu
# Processing Record 36 of Set 6 | xai-xai
# Processing Record 37 of Set 6 | tiznit
# Processing Record 38 of Set 6 | san patricio
# Processing Record 39 of Set 6 | port hardy
# Processing Record 40 of Set 6 | seydi
# Processing Record 41 of Set 6 | zhezkazgan
# Processing Record 42 of Set 6 | kisangani
# Processing Record 43 of Set 6 | kavaratti
# Processing Record 44 of Set 6 | yokadouma
# Processing Record 45 of Set 6 | birao
# Processing Record 46 of Set 6 | goderich
# Processing Record 47 of Set 6 | oranjemund
# Processing Record 48 of Set 6 | cabo san lucas
# Processing Record 49 of Set 6 | bathsheba
# Processing Record 50 of Set 6 | kondinskoye
# Processing Record 1 of Set 7 | ternate
# Processing Record 2 of Set 7 | tarhunah
# City not found. Skipping...
# Processing Record 3 of Set 7 | manavalakurichi
# Processing Record 4 of Set 7 | raudeberg
# Processing Record 5 of Set 7 | cantanhede
# Processing Record 6 of Set 7 | oromocto
# Processing Record 7 of Set 7 | japura
# Processing Record 8 of Set 7 | denpasar
# Processing Record 9 of Set 7 | ikongo
# Processing Record 10 of Set 7 | surab
# Processing Record 11 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 12 of Set 7 | airai
# Processing Record 13 of Set 7 | karpathos
# Processing Record 14 of Set 7 | victoria
# Processing Record 15 of Set 7 | yamada
# Processing Record 16 of Set 7 | port macquarie
# Processing Record 17 of Set 7 | kieta
# Processing Record 18 of Set 7 | lotofaga
# Processing Record 19 of Set 7 | panguna
# Processing Record 20 of Set 7 | kilindoni
# Processing Record 21 of Set 7 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 6 of Set 10 | yar-sale
# Processing Record 7 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 8 of Set 10 | bandarbeyla
# Processing Record 9 of Set 10 | ayagoz
# Processing Record 10 of Set 10 | santa rosa del sur
# Processing Record 11 of Set 10 | camargo
# Processing Record 12 of Set 10 | skerries
# Processing Record 13 of Set 10 | yumen
# Processing Record 14 of Set 10 | tadine
# Processing Record 15 of Set 10 | yaan
# Processing Record 16 of Set 10 | ayan
# Processing Record 17 of Set 10 | kurtamysh
# Processing Record 18 of Set 10 | ewa beach
# Processing Record 19 of Set 10 | zhanatas
# City not found. Skipping...
# Processing Record 20 of Set 10 | paraiso
# Processing Record 21 of Set 10 | kerki
# City not found. Skipping...
# Processing Record 22 of Set 10 | appleton
# Processing Record 23 of Set 10 | lodwar
# Processing Record 24 of Set 10 | srandakan
# Processing Record 25 of Set 10 | oranjestad
# Processing Record 26 of Set 10 | malakal
# Processing Record 27 of Set 10 | kizema
# Processing Record 28 of Set 10 | mezhdurechensk
# Processing Record 29 of Set 10 | svetlyy
# Processing Record 30 of Set 10 | ewo
# Processing Record 31 of Set 10 | viedma
# Processing Record 32 of Set 10 | gorontalo
# Processing Record 33 of Set 10 | zhicheng
# Processing Record 34 of Set 10 | kutum
# Processing Record 35 of Set 10 | temaraia
# City not found. Skipping...
# Processing Record 36 of Set 10 | grand gaube
# Processing Record 37 of Set 10 | turan
# Processing Record 38 of Set 10 | alofi
# Processing Record 39 of Set 10 | quatre cocos
# Processing Record 40 of Set 10 | minab
# Processing Record 41 of Set 10 | eureka
# Processing Record 42 of Set 10 | emerald
# Processing Record 43 of Set 10 | sassandra
# Processing Record 44 of Set 10 | neuhof
# Processing Record 45 of Set 10 | hobyo
# Processing Record 46 of Set 10 | taksimo
# Processing Record 47 of Set 10 | tandlianwala
# Processing Record 48 of Set 10 | sheregesh
# Processing Record 49 of Set 10 | burkhala
# City not found. Skipping...
# Processing Record 50 of Set 10 | gongzhuling
# Processing Record 1 of Set 11 | consett
# Processing Record 2 of Set 11 | havre-saint-pierre
# Processing Record 3 of Set 11 | namibe
# Processing Record 4 of Set 11 | prado
# Processing Record 5 of Set 11 | mundo nuevo
# Processing Record 6 of Set 11 | kayerkan
# Processing Record 7 of Set 11 | bucerias
# Processing Record 8 of Set 11 | piacabucu
# Processing Record 9 of Set 11 | bambanglipuro
# Processing Record 10 of Set 11 | rawson
# Processing Record 11 of Set 11 | stornoway
# Processing Record 12 of Set 11 | calvinia
# Processing Record 13 of Set 11 | presidencia roque saenz pena
# Processing Record 14 of Set 11 | komsomolskiy
# Processing Record 15 of Set 11 | lorengau
# Processing Record 16 of Set 11 | narsaq
# Processing Record 17 of Set 11 | mlimba
# Processing Record 18 of Set 11 | bagacay
# Processing Record 19 of Set 11 | karkaralinsk
# City not found. Skipping...
# Processing Record 20 of Set 11 | cardston
# Processing Record 21 of Set 11 | sitka
# Processing Record 22 of Set 11 | coromandel
# Processing Record 23 of Set 11 | vardo
# Processing Record 24 of Set 11 | port keats
# Processing Record 25 of Set 11 | werda
# Processing Record 26 of Set 11 | golden
# Processing Record 27 of Set 11 | larsnes
# Processing Record 28 of Set 11 | moiyabana
# City not found. Skipping...
# Processing Record 29 of Set 11 | mareeba
# Processing Record 30 of Set 11 | lubango
# Processing Record 31 of Set 11 | caibarien
# Processing Record 32 of Set 11 | penzance
# Processing Record 33 of Set 11 | ostersund
# Processing Record 34 of Set 11 | aklavik
# Processing Record 35 of Set 11 | dolores
# Processing Record 36 of Set 11 | quelimane
# Processing Record 37 of Set 11 | louis trichardt
# Processing Record 38 of Set 11 | blagoyevo
# Processing Record 39 of Set 11 | krasnoselkup
# Processing Record 40 of Set 11 | gladstone
# Processing Record 41 of Set 11 | wenling
# Processing Record 42 of Set 11 | tyret pervaya
# Processing Record 43 of Set 11 | umm ruwabah
# City not found. Skipping...
# Processing Record 44 of Set 11 | atherton
# Processing Record 45 of Set 11 | sola
# Processing Record 46 of Set 11 | nola
# Processing Record 47 of Set 11 | hambantota
# Processing Record 48 of Set 11 | ponot
# Processing Record 49 of Set 11 | hovd
# Processing Record 50 of Set 11 | sao geraldo do araguaia
# Processing Record 1 of Set 12 | lichinga
# Processing Record 2 of Set 12 | planegg
# Processing Record 3 of Set 12 | likhoslavl
# Processing Record 4 of Set 12 | ruteng
# Processing Record 5 of Set 12 | bibiani
# Processing Record 6 of Set 12 | ledyard
# Processing Record 7 of Set 12 | burnie
# Processing Record 8 of Set 12 | los algarrobos
# Processing Record 9 of Set 12 | gorkovskiy
# Processing Record 10 of Set 12 | formoso do araguaia
# City not found. Skipping...
# Processing Record 11 of Set 12 | lugovskiy
# City not found. Skipping...
# Processing Record 12 of Set 12 | kaliganj
# Processing Record 13 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 14 of Set 12 | camocim
# Processing Record 15 of Set 12 | leiyang
# Processing Record 16 of Set 12 | mendi
# Processing Record 17 of Set 12 | ancud
# Processing Record 18 of Set 12 | saint-augustin
# Processing Record 19 of Set 12 | esperance
# Processing Record 20 of Set 12 | omboue
# Processing Record 21 of Set 12 | subate
# Processing Record 22 of Set 12 | csanadapaca
# Processing Record 23 of Set 12 | aketi
# Processing Record 24 of Set 12 | liverpool
# Processing Record 25 of Set 12 | kampong thum
# Processing Record 26 of Set 12 | mongoumba
# Processing Record 27 of Set 12 | west wendover
# Processing Record 28 of Set 12 | amderma
# City not found. Skipping...
# Processing Record 29 of Set 12 | avera
# Processing Record 30 of Set 12 | wukari
# Processing Record 31 of Set 12 | afyonkarahisar
# Processing Record 32 of Set 12 | zatoka
# Processing Record 33 of Set 12 | nerchinskiy zavod
# Processing Record 34 of Set 12 | florianopolis
# Processing Record 35 of Set 12 | benguela
# Processing Record 36 of Set 12 | derzhavinsk
# Processing Record 37 of Set 12 | mackay
# Processing Record 38 of Set 12 | mahdalynivka
# Processing Record 39 of Set 12 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 40 of Set 12 | solnechnyy
# Processing Record 41 of Set 12 | san borja
# Processing Record 42 of Set 12 | haines junction
# Processing Record 43 of Set 12 | maba
# Processing Record 44 of Set 12 | nantucket
# Processing Record 45 of Set 12 | flin flon
# Processing Record 46 of Set 12 | loughton
# Processing Record 47 of Set 12 | tobermory
# Processing Record 48 of Set 12 | ngunguru
# Processing Record 49 of Set 12 | dzhusaly
# City not found. Skipping...
# Processing Record 50 of Set 12 | ruatoria
# City not found. Skipping...
# Processing Record 1 of Set 13 | hojai
# Processing Record 2 of Set 13 | kondoa
# Processing Record 3 of Set 13 | zacoalco
# City not found. Skipping...
# Processing Record 4 of Set 13 | bosaso
# Processing Record 5 of Set 13 | maniitsoq
# Processing Record 6 of Set 13 | inirida
# Processing Record 7 of Set 13 | porto san giorgio
# Processing Record 8 of Set 13 | xghajra
# City not found. Skipping...
# Data Retrieval Complete
# ------------------------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Convert raw data to dataframe

city_weather_df = pd.DataFrame({
    "City": cities,
    "Cloudiness": cloudiness,
    "Country": country,
    "Date": date,
    "Humidity": humidity,
    "Latitude": lat,
    "Longitude": lon,
    "Max Temp": temp_max,
    "Wind Speed": wind_speed
})

# Drop any cities that were skipped because they could not be found using the OpenWeatherMap API

city_weather_df = city_weather_df.dropna(how="any")
print(city_weather_df.count())

# Export the city data into a .csv file

city_weather_df.to_csv("../output_data/cities.csv", index=False)

# Display the DataFrame

weather_df = pd.read_csv("../output_data/cities.csv")
# Out:
# City          554
# Cloudiness    554
# Country       554
# Date          554
# Humidity      554
# Latitude      554
# Longitude     554
# Max Temp      554
# Wind Speed    554
# dtype: int64

# %%
weather_df.head()
# Out:
#              City  Cloudiness Country          Date  Humidity  Latitude  \
# 0         ushuaia        40.0      AR  1.592842e+09      86.0    -54.80
# 1            poum        17.0      NC  1.592842e+09      77.0    -20.23
# 2          avarua         0.0      CK  1.592842e+09      69.0    -21.21
# 3  severiano melo         4.0      BR  1.592842e+09      41.0     -5.78
# 4           akure        98.0      NG  1.592842e+09      84.0      7.25
#
#    Longitude  Max Temp  Wind Speed
# 0     -68.30     33.80        5.82
# 1     164.02     72.46       10.87
# 2    -159.78     73.40       13.87
# 3     -37.96     88.39       11.68
# 4       5.19     77.92        3.80

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %%
# Extract relevant fields from the data frame


# Export the City_Data into a csv

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Create a scatter plot for latitude vs max temperature.

x_values = weather_df['Latitude']
y_values = weather_df['Max Temp']
plt.scatter(x_values, y_values)
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
plt.title("Temperature vs Latitude ")
plt.savefig("../Images/temperature_vs_latitude.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Create a scatter plot for latitude vs humidity.

x_values = weather_df['Latitude']
y_values = weather_df['Humidity']
plt.scatter(x_values, y_values)
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Humidity vs Latitude')
plt.ylim(0, 150)
plt.savefig("../Images/humidity_vs_latitude.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Create a scatter plot for latitude vs cloudiness.

x_values = weather_df['Latitude']
y_values = weather_df['Cloudiness']
plt.scatter(x_values, y_values)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Cloudiness vs Latitude')
plt.savefig("../Images/cloudiness_vs_latitude.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Create a scatter plot for latitude vs wind speed.

x_values = weather_df['Latitude']
y_values = weather_df['Wind Speed']
plt.scatter(x_values, y_values)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Wind Speed vs Latitude')
plt.savefig("../Images/wind_speed_vs_latitude.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

def createLinearRegressionPlot(x_values, y_values, x_label, y_label, hemisphere, line_placement, ylim=None):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

    # Get regression values
    
    regress_values = x_values * slope + intercept
    
    # Create line equation string
    
    line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
    
    plt.scatter(x_values, y_values)
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    if ylim is not None:
        plt.ylim(0, ylim)
    plt.title(f"{hemisphere} Hemisphere - {x_label} vs {y_label}")
    plt.annotate(line_eq,line_placement,fontsize=15,color="red")
    
    # Print r square value
    
    print(f"The r-squared is: {rvalue**2}")
    correlation = st.pearsonr(x_values,y_values)
    print(f"The correlation between both factors is {round(correlation[0],2)}")
    plt.savefig(f"../Images/{hemisphere}_{y_label}_vs_{x_label}.png", bbox_inches="tight")
    return plt.plot(x_values,regress_values,"r-")


#determine northern and southern hemisphere cities

northern_hemisphere = []
southern_hemisphere = []

for index, row in weather_df.iterrows():

    if row["Latitude"] > 0:
        northern_hemisphere.append(row)
    else:
        southern_hemisphere.append(row)

# %%
# Create Northern and Southern Hemisphere DataFrames

northern_hemisphere_df = pd.DataFrame(northern_hemisphere)
southern_hemisphere_df = pd.DataFrame(southern_hemisphere)

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Create a scatter plot for latitude vs max temp (northern hemisphere)

x_values = northern_hemisphere_df['Latitude']
y_values = northern_hemisphere_df['Max Temp']
createLinearRegressionPlot(x_values, y_values, "Latitude", "Max Temp (F)", "Northern",(0, 0))
# Out:
# The r-squared is: 0.5024339048234246
# The correlation between both factors is -0.71

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Create a scatter plot for latitude vs max temp (southern hemisphere)

x_values = southern_hemisphere_df['Latitude']
y_values = southern_hemisphere_df['Max Temp']
createLinearRegressionPlot(x_values, y_values, "Latitude", "Max Temp (F)", "Southern",(-30, 50))
# Out:
# The r-squared is: 0.6211567624274846
# The correlation between both factors is 0.79

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Create a scatter plot for latitude vs humditiy (northern hemisphere)

x_values = northern_hemisphere_df['Latitude']
y_values = northern_hemisphere_df['Humidity']
createLinearRegressionPlot(x_values, y_values, "Latitude", "Humidity (%)", "Northern",(40, 20))
# Out:
# The r-squared is: 0.00019391038950457144
# The correlation between both factors is -0.01

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Create a scatter plot for latitude vs humditiy (southern hemisphere)

x_values1 = southern_hemisphere_df['Latitude']
y_values1 = southern_hemisphere_df['Humidity']
createLinearRegressionPlot(x_values, y_values, "Latitude", "Humidity (%)", "Southern",(40, 20), 150)
# Out:
# The r-squared is: 0.00019391038950457144
# The correlation between both factors is -0.01

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Create a scatter plot for latitude vs cloudiness (northern hemisphere)

x_values = northern_hemisphere_df['Latitude']
y_values = northern_hemisphere_df['Cloudiness']
createLinearRegressionPlot(x_values, y_values, "Latitude", "Cloudiness(%)", "Northern",(30, 50))
# Out:
# The r-squared is: 0.002755373605306556
# The correlation between both factors is -0.05

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Create a scatter plot for latitude vs cloudiness (southern hemisphere)

x_values = southern_hemisphere_df['Latitude']
y_values = southern_hemisphere_df['Cloudiness']
createLinearRegressionPlot(x_values, y_values, "Latitude", "Cloudiness(%)", "Southern",(-45, 60))
# Out:
# The r-squared is: 0.0004635958034115161
# The correlation between both factors is 0.02

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Create a scatter plot for latitude vs wind speed(northern hemisphere)

x_values = northern_hemisphere_df['Latitude']
y_values = northern_hemisphere_df['Wind Speed']
createLinearRegressionPlot(x_values, y_values, "Latitude", "Wind Speed (mph)", "Northern",(20, 25))
# Out:
# The r-squared is: 0.0019158404368803434
# The correlation between both factors is 0.04

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Create a scatter plot for latitude vs wind speed (southern hemisphere)

x_values = southern_hemisphere_df['Latitude']
y_values = southern_hemisphere_df['Wind Speed']
createLinearRegressionPlot(x_values, y_values, "Latitude", "Wind Speed (mph)", "Southern",(-40, 25), ylim=40)
# Out:
# The r-squared is: 0.00929906681882783
# The correlation between both factors is -0.1
